# %% [markdown]
# # School DataFrame
#
# #### Version: 1
# #### Creation Date: 2/5/21
# #### File Names Generated: school_df_v1.csv

# %% [markdown]
# #### Notes:
# * initial compilation of school information into school specific dataframe

# %% [markdown]
# ---

# %% [markdown]
# COLUMN NAMES:
# * 'attnd_absence_1-5_SY1718',
# * 'attnd_absence_1-5_SY1819',
# * 'attnd_absence_11-20_SY1718',
# * 'attnd_absence_11-20_SY1819',
# * 'attnd_absence_20+_SY1718',
# * 'attnd_absence_20+_SY1819',
# * 'attnd_absence_6-10_SY1718',
# * 'attnd_absence_6-10_SY1819',
# * 'attnd_count_truancy_aged_students_SY1718',
# * 'attnd_count_truancy_aged_students_SY1819',
# * 'school_capacity_SY1718',
# * 'school_capacity_SY1819',
# * 'school_cluster',
# * 'school_code',
# * 'school_enrollment_SY1718',
# * 'school_enrollment_SY1819',
# * 'school_grade_band',
# * 'school_grade_range',
# * 'school_latitude',
# * 'school_longitude',
# * 'school_name',
# * 'school_sector',
# * 'school_star_rating_SY1718',
# * 'school_star_rating_SY1819',
# * 'school_star_score_SY1718',
# * 'school_star_score_SY1819',
# * 'school_unfilled_seats_SY1718',
# * 'school_unfilled_seats_SY1819',
# * 'school_ward'

# %% [markdown]
# ---

# %% [markdown]
# <br><Br>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <br><br>

# %%
schools = pd.read_excel('../../01_data/original_data/schools_cleaned.xlsx')

# %%
schools.head(2)
# Out:
#    school_code                                     school_name  \
# 0          101              Maya Angelou PCS-Evans High School
# 1          102  Cesar Chavez for Public Policy-Parkside MS PCS
#
#                     school_type  cluster    Cluster  charter_status  \
# 0  Alternative Education School     33.0  Cluster 33            Yes
# 1                Regular school     30.0  Cluster 30            Yes
#
#     latitude  longitude  ward  zipcode  census_tract  lea_code  \
# 0  38.890291 -76.920635   7.0  20019.0        7808.0       133
# 1  38.901438 -76.949065   7.0  20019.0        9602.0       109
#
#            lea_name
# 0  Maya Angelou PCS
# 1  Cesar Chavez PCS

# %%
schools.drop(columns = ['cluster', 'charter_status', 'census_tract', 'zipcode'], axis = 1, inplace = True)

# %%
schools.rename(columns={
    'Cluster ':'school_cluster',
    'ward':'school_ward',
    'latitude':'school_latitude',
    'longitude':'school_longitude'
}, inplace=True)

# %%
schools['school_code']=schools['school_code'].astype(float)

# %%
schools.head(2)
# Out:
#    school_code                                     school_name  \
# 0        101.0              Maya Angelou PCS-Evans High School
# 1        102.0  Cesar Chavez for Public Policy-Parkside MS PCS
#
#                     school_type school_cluster  school_latitude  \
# 0  Alternative Education School     Cluster 33        38.890291
# 1                Regular school     Cluster 30        38.901438
#
#    school_longitude  school_ward  lea_code          lea_name
# 0        -76.920635          7.0       133  Maya Angelou PCS
# 1        -76.949065          7.0       109  Cesar Chavez PCS

# %% [markdown]
# <br><br>

# %%
#attendance 
attnd_1718 = pd.read_excel('../data/from_drive/school_attendance.xlsx',sheet_name='SY_17_18')

# %%
attnd_1718.head(2)
# Out:
#    school_code                     School Name School Name - short  \
# 0          202         Aiton Elementary School            Aiton ES
# 1          203  Amidon-Bowen Elementary School     Amidon-Bowen ES
#
#    Truancy Aged Students # 1-5 Absences #6-10 Absences #11-20 Absences  \
# 0                    190             74             58              33
# 1                    309            149             98              36
#
#   #21+ Absences       Year
# 0            12  2017-2018
# 1            12  2017-2018

# %%
attnd_1718.columns
# Out:
# Index(['school_code', 'School Name', 'School Name - short',
#        'Truancy Aged Students', '# 1-5 Absences', '#6-10 Absences',
#        '#11-20 Absences', '#21+ Absences', 'Year'],
#       dtype='object')

# %%
attnd_1718.drop(columns = ["Year", 'School Name - short'], inplace=True)

# %%
attnd_1718.rename(columns={
    'School Name':'school_name',
    'Truancy Aged Students':'attnd_count_truancy_aged_students_SY1718',
    '# 1-5 Absences':'attnd_absence_1-5_SY1718',
    '#6-10 Absences':'attnd_absence_6-10_SY1718',
    '#11-20 Absences':'attnd_absence_11-20_SY1718',
    '#21+ Absences':'attnd_absence_20+_SY1718'
}, inplace=True)

# %%
attnd_1718.head(2)
# Out:
#    school_code                     school_name  \
# 0          202         Aiton Elementary School
# 1          203  Amidon-Bowen Elementary School
#
#    attnd_count_truancy_aged_students_SY1718 attnd_absence_1-5_SY1718  \
# 0                                       190                       74
# 1                                       309                      149
#
#   attnd_absence_6-10_SY1718 attnd_absence_11-20_SY1718  \
# 0                        58                         33
# 1                        98                         36
#
#   attnd_absence_20+_SY1718
# 0                       12
# 1                       12

# %%
# numeric_columns = ['school_code', 'attnd_count_truancy_aged_students_SY1718', 'attnd_absence_1-5_SY1718', 'attnd_absence_6-10_SY1718', 'attnd_absence_11-20_SY1718', 'attnd_absence_20+_SY1718']

# attnd_1718[numeric_columns].astype(int)

# %% [raw]
# attnd_1718.set_index('school_code', drop = True, inplace=True)

# %%
attnd_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   school_code                               115 non-null    int64
#  1   school_name                               115 non-null    object
#  2   attnd_count_truancy_aged_students_SY1718  115 non-null    int64
#  3   attnd_absence_1-5_SY1718                  115 non-null    object
#  4   attnd_absence_6-10_SY1718                 115 non-null    object
#  5   attnd_absence_11-20_SY1718                115 non-null    object
#  6   attnd_absence_20+_SY1718                  115 non-null    object
# dtypes: int64(2), object(5)
# memory usage: 6.4+ KB

# %% [markdown]
# <br><br>

# %%
attnd_1819 = pd.read_excel('../data/from_drive/school_attendance.xlsx',sheet_name='SY_18_19')

# %%
attnd_1819.head(2)
# Out:
#    school_code                     School Name School Name - short  \
# 0        202.0         Aiton Elementary School            Aiton ES
# 1        203.0  Amidon-Bowen Elementary School     Amidon-Bowen ES
#
#   Truancy Aged Students # 1-5 Absences #6-10 Absences #11-20 Absences  \
# 0                   190             58             61              45
# 1                   279            132             87              38
#
#   #21+ Absences       Year
# 0            21  2018-2019
# 1            10  2018-2019

# %%
attnd_1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   school_code            115 non-null    float64
#  1   School Name            115 non-null    object
#  2   School Name - short    115 non-null    object
#  3   Truancy Aged Students  115 non-null    object
#  4   # 1-5 Absences         115 non-null    object
#  5   #6-10 Absences         115 non-null    object
#  6   #11-20 Absences        115 non-null    object
#  7   #21+ Absences          110 non-null    object
#  8   Year                   35 non-null     object
# dtypes: float64(1), object(8)
# memory usage: 8.5+ KB

# %%
attnd_1819.columns
# Out:
# Index(['school_code', 'School Name', 'School Name - short',
#        'Truancy Aged Students', '# 1-5 Absences', '#6-10 Absences',
#        '#11-20 Absences', '#21+ Absences', 'Year'],
#       dtype='object')

# %%
attnd_1819.drop(columns = ["Year", 'School Name - short'], inplace=True)

# %%
attnd_1819.rename(columns={
    'School Name':'school_name',
    'Truancy Aged Students':'attnd_count_truancy_aged_students_SY1819',
    '# 1-5 Absences':'attnd_absence_1-5_SY1819',
    '#6-10 Absences':'attnd_absence_6-10_SY1819',
    '#11-20 Absences':'attnd_absence_11-20_SY1819',
    '#21+ Absences':'attnd_absence_20+_SY1819'
}, inplace=True)

# %% [raw]
# attnd_1819.set_index('school_code', drop = True, inplace=True)

# %%
attnd_1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119 entries, 0 to 118
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   school_code                               115 non-null    float64
#  1   school_name                               115 non-null    object
#  2   attnd_count_truancy_aged_students_SY1819  115 non-null    object
#  3   attnd_absence_1-5_SY1819                  115 non-null    object
#  4   attnd_absence_6-10_SY1819                 115 non-null    object
#  5   attnd_absence_11-20_SY1819                115 non-null    object
#  6   attnd_absence_20+_SY1819                  110 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 6.6+ KB

# %%
attnd_1819.tail()
# Out:
#      school_code            school_name  \
# 114        861.0  Youth Services Center
# 115          NaN                    NaN
# 116          NaN                    NaN
# 117          NaN                    NaN
# 118          NaN                    NaN
#
#     attnd_count_truancy_aged_students_SY1819 attnd_absence_1-5_SY1819  \
# 114                                      118                       28
# 115                                      NaN                      NaN
# 116                                      NaN                      NaN
# 117                                      NaN                      NaN
# 118                                      NaN                      NaN
#
#     attnd_absence_6-10_SY1819 attnd_absence_11-20_SY1819  \
# 114                        15                       n<10
# 115                       NaN                        NaN
# 116                       NaN                        NaN
# 117                       NaN                        NaN
# ...

# %%
attnd_1819 = attnd_1819[:-4]

# %% [markdown]
# <br><br>

# %%
enroll_1819 = pd.read_excel('../data/from_drive/enrollment_school_facility_dcps.xlsx', sheet_name='enrollment_by_school_1819')

# %%
enroll_1819.head(2)
# Out:
#   School Year Facility Sector  School Code  LEA Code  \
# 0     SY18-19            DCPS        202.0       1.0
# 1     SY18-19            DCPS        203.0       1.0
#
#                       School Name School Grade Range  Audited Enrollment  \
# 0         Aiton Elementary School            PK3-5th               244.0
# 1  Amidon-Bowen Elementary School            PK3-5th               339.0
#
#    School STAR Score  School STAR Rating  Capacity  Unfilled Seats      MAR X  \
# 0              10.79                 1.0     529.0           285.0  405751.28
# 1              48.54                 3.0     400.0            61.0  398427.29
#
#        MAR Y  MAR Latitude  MAR Longitude Neighborhood Cluster    Ward  \
# 0  136574.53     38.897002     -76.933701           Cluster 31  Ward 7
# 1  134631.47     38.879515     -77.018125            Cluster 9  Ward 6
#
#   Unique Grade Band
# 0        Elementary
# 1        Elementary

# %%
enroll_1819.columns
# Out:
# Index(['School Year', 'Facility Sector', 'School Code', 'LEA Code',
#        'School Name', 'School Grade Range', 'Audited Enrollment',
#        'School STAR Score', 'School STAR Rating', 'Capacity', 'Unfilled Seats',
#        'MAR X', 'MAR Y', 'MAR Latitude', 'MAR Longitude',
#        'Neighborhood Cluster', 'Ward', 'Unique Grade Band'],
#       dtype='object')

# %%
enroll_1819.rename(columns={
    'Facility Sector':'school_sector', 
    'School Code':'school_code', 
    'School Name':'school_name', 
    'School Grade Range':'school_grade_range',
    'Unique Grade Band':'school_grade_band',
    'Audited Enrollment':'school_enrollment_SY1819',
    'School STAR Score':'school_star_score_SY1819', 
    'School STAR Rating':'school_star_rating_SY1819', 
    'Capacity':'school_capacity_SY1819', 
    'Unfilled Seats':'school_unfilled_seats_SY1819',
    'MAR Latitude':'school_latitude', 
    'MAR Longitude':'school_longitude',
    'Neighborhood Cluster':'school_cluster', 
    'Ward':'school_ward'
}, inplace=True)

enroll_1819.drop(columns = ['LEA Code','School Year', 'MAR X', 'MAR Y'], axis = 1, inplace = True)

# %%
enroll_1819['school_code']=enroll_1819['school_code'].astype(float)

# %% [raw]
# enroll_1819.set_index('school_code', drop = True, inplace=True)

# %%
enroll_1819 = enroll_1819[enroll_1819['school_sector'] == 'DCPS']

# %%
enroll_1819.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 115 entries, 0 to 114
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   school_sector                 115 non-null    object
#  1   school_code                   115 non-null    float64
#  2   school_name                   115 non-null    object
#  3   school_grade_range            115 non-null    object
#  4   school_enrollment_SY1819      115 non-null    float64
#  5   school_star_score_SY1819      108 non-null    float64
#  6   school_star_rating_SY1819     108 non-null    float64
#  7   school_capacity_SY1819        107 non-null    float64
#  8   school_unfilled_seats_SY1819  107 non-null    float64
#  9   school_latitude               115 non-null    float64
#  10  school_longitude              115 non-null    float64
#  11  school_cluster                115 non-null    object
# ...

# %%
enroll_1819.tail(2)
# Out:
#     school_sector  school_code               school_name school_grade_range  \
# 113          DCPS        464.0  Woodson, H D High School           9th-12th
# 114          DCPS        861.0     Youth Services Center        Alternative
#
#      school_enrollment_SY1819  school_star_score_SY1819  \
# 113                     455.0                     18.34
# 114                      31.0                       NaN
#
#      school_star_rating_SY1819  school_capacity_SY1819  \
# 113                        1.0                  1000.0
# 114                        NaN                     0.0
#
#      school_unfilled_seats_SY1819  school_latitude  school_longitude  \
# 113                         545.0        38.896787        -76.922328
# 114                           0.0        38.912140        -76.988586
#
#     school_cluster school_ward school_grade_band
# 113     Cluster 31      Ward 7              High
# 114     Cluster 23      Ward 5         Adult/Alt

# %% [markdown]
# <br><br>

# %%
enroll_1718 = pd.read_excel('../data/from_drive/enrollment_school_facility_dcps.xlsx', sheet_name='enrollment_by_school_1718')

# %%
enroll_1718.head(2)
# Out:
#   School Year Facility Sector  School Code  LEA Code  \
# 0     SY17-18            DCPS        202.0       1.0
# 1     SY17-18            DCPS        203.0       1.0
#
#                       School Name School Grade Range  Audited Enrollment  \
# 0         Aiton Elementary School            PK3-5th               243.0
# 1  Amidon Bowen Elementary School            PK3-5th               351.0
#
#    School STAR Score  School STAR Rating  Capacity  Unfilled Seats      MAR X  \
# 0              43.85                 3.0     529.0           286.0  405751.28
# 1              36.53                 2.0     400.0            49.0  398427.29
#
#        MAR Y  MAR Latitude  MAR Longitude Neighborhood Cluster    Ward  \
# 0  136574.53     38.897002     -76.933701           Cluster 31  Ward 7
# 1  134631.47     38.879515     -77.018125            Cluster 9  Ward 6
#
#   Unique Grade Band
# 0        Elementary
# 1        Elementary

# %%
enroll_1718.columns
# Out:
# Index(['School Year', 'Facility Sector', 'School Code', 'LEA Code',
#        'School Name', 'School Grade Range', 'Audited Enrollment',
#        'School STAR Score', 'School STAR Rating', 'Capacity', 'Unfilled Seats',
#        'MAR X', 'MAR Y', 'MAR Latitude', 'MAR Longitude',
#        'Neighborhood Cluster', 'Ward', 'Unique Grade Band'],
#       dtype='object')

# %%
enroll_1718.rename(columns={
    'Facility Sector':'school_sector', 
    'School Code':'school_code', 
    'School Name':'school_name', 
    'School Grade Range':'school_grade_range',
    'Unique Grade Band':'school_grade_band',
    'Audited Enrollment':'school_enrollment_SY1718',
    'School STAR Score':'school_star_score_SY1718', 
    'School STAR Rating':'school_star_rating_SY1718', 
    'Capacity':'school_capacity_SY1718', 
    'Unfilled Seats':'school_unfilled_seats_SY1718',
    'MAR Latitude':'school_latitude', 
    'MAR Longitude':'school_longitude',
    'Neighborhood Cluster':'school_cluster', 
    'Ward':'school_ward'
}, inplace=True)

enroll_1718.drop(columns = ['LEA Code','School Year', 'MAR X', 'MAR Y'], axis = 1, inplace = True)

# %%
enroll_1718['school_code']=enroll_1718['school_code'].astype(float)

# %%
enroll_1718 = enroll_1718[enroll_1718['school_sector'] == 'DCPS']

# %%
enroll_1718.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 0 to 113
# Data columns (total 14 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   school_sector                 114 non-null    object
#  1   school_code                   114 non-null    float64
#  2   school_name                   114 non-null    object
#  3   school_grade_range            114 non-null    object
#  4   school_enrollment_SY1718      114 non-null    float64
#  5   school_star_score_SY1718      107 non-null    float64
#  6   school_star_rating_SY1718     107 non-null    float64
#  7   school_capacity_SY1718        106 non-null    float64
#  8   school_unfilled_seats_SY1718  106 non-null    float64
#  9   school_latitude               114 non-null    float64
#  10  school_longitude              114 non-null    float64
#  11  school_cluster                114 non-null    object
# ...

# %% [raw]
# enroll_1718.set_index('school_code', drop = True, inplace=True)

# %% [markdown]
# <br><br>

# %%
school_df = enroll_1819

# %%
school_df.head(2)
# Out:
#   school_sector  school_code                     school_name  \
# 0          DCPS        202.0         Aiton Elementary School
# 1          DCPS        203.0  Amidon-Bowen Elementary School
#
#   school_grade_range  school_enrollment_SY1819  school_star_score_SY1819  \
# 0            PK3-5th                     244.0                     10.79
# 1            PK3-5th                     339.0                     48.54
#
#    school_star_rating_SY1819  school_capacity_SY1819  \
# 0                        1.0                   529.0
# 1                        3.0                   400.0
#
#    school_unfilled_seats_SY1819  school_latitude  school_longitude  \
# 0                         285.0        38.897002        -76.933701
# 1                          61.0        38.879515        -77.018125
#
#   school_cluster school_ward school_grade_band
# 0     Cluster 31      Ward 7        Elementary
# 1      Cluster 9      Ward 6        Elementary

# %% [raw]
# school_df.set_index('school_code', drop = True, inplace=True)

# %%
school_df.head(2)
# Out:
#   school_sector  school_code                     school_name  \
# 0          DCPS        202.0         Aiton Elementary School
# 1          DCPS        203.0  Amidon-Bowen Elementary School
#
#   school_grade_range  school_enrollment_SY1819  school_star_score_SY1819  \
# 0            PK3-5th                     244.0                     10.79
# 1            PK3-5th                     339.0                     48.54
#
#    school_star_rating_SY1819  school_capacity_SY1819  \
# 0                        1.0                   529.0
# 1                        3.0                   400.0
#
#    school_unfilled_seats_SY1819  school_latitude  school_longitude  \
# 0                         285.0        38.897002        -76.933701
# 1                          61.0        38.879515        -77.018125
#
#   school_cluster school_ward school_grade_band
# 0     Cluster 31      Ward 7        Elementary
# 1      Cluster 9      Ward 6        Elementary

# %%
grab_section = enroll_1718.filter(regex='\d')
grab_section['school_code']=enroll_1718['school_code']
grab_section.head(2)
# Out:
# <ipython-input-56-90bfb0596d00>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grab_section['school_code']=enroll_1718['school_code']
#    school_enrollment_SY1718  school_star_score_SY1718  \
# 0                     243.0                     43.85
# 1                     351.0                     36.53
#
#    school_star_rating_SY1718  school_capacity_SY1718  \
# 0                        3.0                   529.0
# 1                        2.0                   400.0
#
#    school_unfilled_seats_SY1718  school_code
# 0                         286.0        202.0
# 1                          49.0        203.0

# %%
school_df = school_df.join(grab_section.set_index('school_code'),on='school_code',how='left')

# %% [raw]
# school_df.dropna(how='all', inplace=True)

# %%
school_df
# Out:
#     school_sector  school_code                     school_name  \
# 0            DCPS        202.0         Aiton Elementary School
# 1            DCPS        203.0  Amidon-Bowen Elementary School
# 2            DCPS        450.0           Anacostia High School
# 3            DCPS        452.0              Ballou High School
# 4            DCPS        462.0                     Ballou STAY
# ..            ...          ...                             ...
# 110          DCPS        335.0       Wheatley Education Campus
# 111          DCPS        338.0       Whittier Education Campus
# 112          DCPS        463.0              Wilson High School
# 113          DCPS        464.0        Woodson, H D High School
# 114          DCPS        861.0           Youth Services Center
#
#     school_grade_range  school_enrollment_SY1819  school_star_score_SY1819  \
# 0              PK3-5th                     244.0                     10.79
# ...

# %% [markdown]
# <br><br>

# %%
grab_section = attnd_1819.filter(regex='\d')
grab_section['school_code']=attnd_1819['school_code']
grab_section.head(2)
# Out:
# <ipython-input-59-aac910ac4b91>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grab_section['school_code']=attnd_1819['school_code']
#   attnd_count_truancy_aged_students_SY1819 attnd_absence_1-5_SY1819  \
# 0                                      190                       58
# 1                                      279                      132
#
#   attnd_absence_6-10_SY1819 attnd_absence_11-20_SY1819  \
# 0                        61                         45
# 1                        87                         38
#
#   attnd_absence_20+_SY1819  school_code
# 0                       21        202.0
# 1                       10        203.0

# %%
school_df = school_df.join(grab_section.set_index('school_code'),on='school_code',how='left')

# %%
grab_section = attnd_1718.filter(regex='\d')
grab_section['school_code']=attnd_1718['school_code']
grab_section.head(2)
# Out:
# <ipython-input-61-2e0247f47eab>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   grab_section['school_code']=attnd_1718['school_code']
#    attnd_count_truancy_aged_students_SY1718 attnd_absence_1-5_SY1718  \
# 0                                       190                       74
# 1                                       309                      149
#
#   attnd_absence_6-10_SY1718 attnd_absence_11-20_SY1718  \
# 0                        58                         33
# 1                        98                         36
#
#   attnd_absence_20+_SY1718  school_code
# 0                       12          202
# 1                       12          203

# %%
school_df = school_df.join(grab_section.set_index('school_code'),on='school_code',how='left')

# %%
school_df = school_df[school_df['school_sector'] == 'DCPS']

# %%
school_df
# Out:
#     school_sector  school_code                     school_name  \
# 0            DCPS          202         Aiton Elementary School
# 1            DCPS          203  Amidon-Bowen Elementary School
# 2            DCPS          450           Anacostia High School
# 3            DCPS          452              Ballou High School
# 4            DCPS          462                     Ballou STAY
# ..            ...          ...                             ...
# 110          DCPS          335       Wheatley Education Campus
# 111          DCPS          338       Whittier Education Campus
# 112          DCPS          463              Wilson High School
# 113          DCPS          464        Woodson, H D High School
# 114          DCPS          861           Youth Services Center
#
#     school_grade_range  school_enrollment_SY1819  school_star_score_SY1819  \
# 0              PK3-5th                     244.0                     10.79
# ...

# %%
school_df.columns.sort_values()
# Out:
# Index(['attnd_absence_1-5_SY1718', 'attnd_absence_1-5_SY1819',
#        'attnd_absence_11-20_SY1718', 'attnd_absence_11-20_SY1819',
#        'attnd_absence_20+_SY1718', 'attnd_absence_20+_SY1819',
#        'attnd_absence_6-10_SY1718', 'attnd_absence_6-10_SY1819',
#        'attnd_count_truancy_aged_students_SY1718',
#        'attnd_count_truancy_aged_students_SY1819', 'school_capacity_SY1718',
#        'school_capacity_SY1819', 'school_cluster', 'school_code',
#        'school_enrollment_SY1718', 'school_enrollment_SY1819',
#        'school_grade_band', 'school_grade_range', 'school_latitude',
#        'school_longitude', 'school_name', 'school_sector',
#        'school_star_rating_SY1718', 'school_star_rating_SY1819',
#        'school_star_score_SY1718', 'school_star_score_SY1819',
#        'school_unfilled_seats_SY1718', 'school_unfilled_seats_SY1819',
#        'school_ward'],
#       dtype='object')

# %%
school_df['school_code']=school_df['school_code'].astype(int)

# %%
school_df.to_csv('../data/cleaned/school_df_v1.csv', index=False)
