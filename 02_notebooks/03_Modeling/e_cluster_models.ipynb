# %% [markdown]
# ## NOTES:
# * embedded is code to calculate each star school rank breakdown of absences percentages
# * embedded is code to extract school_ward_int and school_cluster_int columns

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from category_encoders import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans, DBSCAN
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA

# %%
data = pd.read_csv('../../01_data/cleaned_data/school_df_v4.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 41 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   code                      109 non-null    int64
#  1   name                      109 non-null    object
#  2   grade_band                109 non-null    object
#  3   enrollment_SY1718         109 non-null    int64
#  4   enrollment_SY1819         109 non-null    int64
#  5   star_score_SY1718         109 non-null    float64
#  6   star_score_SY1819         109 non-null    float64
#  7   star_rating_SY1718        109 non-null    int64
#  8   star_rating_SY1819        109 non-null    int64
#  9   capacity_SY1718           109 non-null    int64
#  10  capacity_SY1819           109 non-null    int64
#  11  latitude                  109 non-null    float64
#  12  longitude                 109 non-null    float64
#  13  cluster                   109 non-null    int64
#  14  ward                      109 non-null    int64
#  15  count_any_SY1819          109 non-null    int64
#  16  count_0_SY1819            109 non-null    int64
#  17  pct_0_SY1819              109 non-null    float64
#  18  count_1-5_SY1819          107 non-null    float64
#  19  pct_1-5_SY1819            109 non-null    float64
#  20  count_6-10_SY1819         107 non-null    float64
#  21  pct_6-10_SY1819           109 non-null    float64
#  22  count_11-20_SY1819        107 non-null    float64
#  23  pct_11-20_SY1819          109 non-null    float64
#  24  count_20+_SY1819          108 non-null    float64
#  25  pct_20+_SY1819            109 non-null    float64
#  26  count_any_SY1718          109 non-null    int64
#  27  count_0_SY1718            109 non-null    int64
#  28  pct_0_SY1718              109 non-null    float64
#  29  count_1-5_SY1718          107 non-null    float64
#  30  pct_1-5_SY1718            109 non-null    float64
#  31  count_6-10_SY1718         107 non-null    float64
#  32  pct_6-10__SY1718          109 non-null    float64
#  33  count_11-20_SY1718        107 non-null    float64
#  34  pct_11-20_SY1718          109 non-null    float64
#  35  count_20+_SY1718          107 non-null    float64
#  36  pct_20+_SY1718            109 non-null    float64
#  37  budgeted_amount_FY16      109 non-null    float64
#  38  budgeted_enrollment_FY16  109 non-null    int64
#  39  budgeted_amount_FY17      109 non-null    int64
#  40  budgeted_enrollment_FY17  109 non-null    int64
# dtypes: float64(23), int64(16), object(2)
# memory usage: 35.0+ KB

# %%
data.drop(data[data['code'] == 201].index, inplace = True) # Oyster Adams Bilingual School (Adams) has no attendance data
data.drop(data[data['code'] == 347].index, inplace = True) # Brookland Middle School has no attendance data

# %%
X = data.drop(columns = data.filter(regex='^count',axis=1)).drop(columns='name')

# %%
X.drop('code', axis = 1, inplace = True)

# %%
X_ohe = OneHotEncoder(cols=['grade_band']).fit_transform(X)
X_ohe
# Out:
# c:\programdata\miniconda3\lib\site-packages\category_encoders\utils.py:21: FutureWarning: is_categorical is deprecated and will be removed in a future version.  Use is_categorical_dtype instead
#   elif pd.api.types.is_categorical(cols):
#      grade_band_1  grade_band_2  grade_band_3  grade_band_4  grade_band_5  \
# 0               1             0             0             0             0
# 2               1             0             0             0             0
# 3               1             0             0             0             0
# 4               1             0             0             0             0
# 5               1             0             0             0             0
# ..            ...           ...           ...           ...           ...
# 104             0             0             0             1             0
# 105             0             0             0             1             0
# 106             0             0             0             1             0
# 107             0             0             0             1             0
# 108             0             0             0             1             0
#
#      enrollment_SY1718  enrollment_SY1819  star_score_SY1718  \
# 0                  308                313              88.55
# 2                  243                244              43.85
# 3                  351                339              36.53
# 4                  642                620              66.46
# 5                  484                489              35.32
# ..                 ...                ...                ...
# 104                617                667              26.57
# 105                566                545              72.66
# 106                195                136              24.88
# 107                260                265              44.70
# 108                251                288              29.69
#
#      star_score_SY1819  star_rating_SY1718  ...  pct_20+_SY1819  pct_0_SY1718  \
# 0                88.26                   5  ...        0.015974      0.379870
# 2                10.79                   3  ...        0.086066      0.271605
# 3                48.54                   2  ...        0.029499      0.159544
# 4                73.18                   4  ...        0.017742      0.323988
# 5                38.68                   2  ...        0.010225      0.371901
# ..                 ...                 ...  ...             ...           ...
# 104              22.24                   2  ...        0.761619     -0.069692
# 105              74.13                   4  ...        0.291743      0.084806
# 106              12.90                   2  ...        0.955882     -0.005128
# 107              54.27                   3  ...        0.283019      0.007692
# 108              -1.00                   2  ...        0.017361      0.286853
#
#      pct_1-5_SY1718  pct_6-10__SY1718  pct_11-20_SY1718  pct_20+_SY1718  \
# 0          0.538961          0.064935          0.016234        0.000000
# 2          0.304527          0.238683          0.135802        0.049383
# 3          0.424501          0.279202          0.102564        0.034188
# 4          0.588785          0.063863          0.015576        0.007788
# 5          0.520661          0.097107          0.010331        0.000000
# ..              ...               ...               ...             ...
# 104        0.059968          0.098865          0.265802        0.645057
# 105        0.395760          0.178445          0.196113        0.144876
# 106        0.025641          0.025641          0.025641        0.928205
# 107        0.134615          0.188462          0.361538        0.307692
# 108        0.067729          0.063745          0.139442        0.442231
#
#      budgeted_amount_FY16  budgeted_enrollment_FY16  budgeted_amount_FY17  \
# 0            1.059280e+07                      5880               3815456
# 2            7.429920e+06                      2650               3780814
# 3            8.979878e+06                      3660               4533018
# 4            1.519980e+07                      6340               7531184
# 5            1.102686e+07                      4340               5511270
# ..                    ...                       ...                   ...
# 104          1.745768e+07                      6860               8919967
# 105          1.243783e+07                      5270               6791997
# 106          7.133322e+06                      2510               3599053
# 107          8.835780e+06                      3610               4196996
# 108          7.232096e+06                      3620               3618704
#
#      budgeted_enrollment_FY17
# 0                     2674740
# 2                     2499672
# 3                     3020358
# 4                     4677607
# 5                     3506981
# ..                        ...
# 104                   5286569
# 105                   3355125
# 106                   2721974
# 107                   2765707
# 108                   2887150
#
# [107 rows x 31 columns]

# %%
X_ohe_ss = StandardScaler().fit_transform(X_ohe)

# %%
kmeans = KMeans()
kmeans.fit(X_ohe_ss)
# Out:
# KMeans()

# %%
kmeans_df = X.copy()
kmeans_df['kmeans_default_labels'] = kmeans.labels_
kmeans_df
# Out:
#      grade_band  enrollment_SY1718  enrollment_SY1819  star_score_SY1718  \
# 0    Elementary                308                313              88.55
# 2    Elementary                243                244              43.85
# 3    Elementary                351                339              36.53
# 4    Elementary                642                620              66.46
# 5    Elementary                484                489              35.32
# ..          ...                ...                ...                ...
# 104        High                617                667              26.57
# 105        High                566                545              72.66
# 106        High                195                136              24.88
# 107        High                260                265              44.70
# 108        High                251                288              29.69
#
#      star_score_SY1819  star_rating_SY1718  star_rating_SY1819  \
# 0                88.26                   5                   5
# 2                10.79                   3                   1
# 3                48.54                   2                   3
# 4                73.18                   4                   4
# 5                38.68                   2                   2
# ..                 ...                 ...                 ...
# 104              22.24                   2                   2
# 105              74.13                   4                   4
# 106              12.90                   2                   1
# 107              54.27                   3                   3
# 108              -1.00                   2                  -1
#
#      capacity_SY1718  capacity_SY1819   latitude  ...  pct_0_SY1718  \
# 0                444              444  38.897565  ...      0.379870
# 2                529              529  38.897002  ...      0.271605
# 3                400              400  38.879515  ...      0.159544
# 4                753              753  38.948231  ...      0.323988
# 5                508              508  38.864350  ...      0.371901
# ..               ...              ...        ...  ...           ...
# 104             1135             1135  38.907627  ...     -0.069692
# 105              600              600  38.913446  ...      0.084806
# 106               -1               -1  38.920430  ...     -0.005128
# 107              512              512  38.901992  ...      0.007692
# 108              350              350  38.932276  ...      0.286853
#
#      pct_1-5_SY1718  pct_6-10__SY1718  pct_11-20_SY1718  pct_20+_SY1718  \
# 0          0.538961          0.064935          0.016234        0.000000
# 2          0.304527          0.238683          0.135802        0.049383
# 3          0.424501          0.279202          0.102564        0.034188
# 4          0.588785          0.063863          0.015576        0.007788
# 5          0.520661          0.097107          0.010331        0.000000
# ..              ...               ...               ...             ...
# 104        0.059968          0.098865          0.265802        0.645057
# 105        0.395760          0.178445          0.196113        0.144876
# 106        0.025641          0.025641          0.025641        0.928205
# 107        0.134615          0.188462          0.361538        0.307692
# 108        0.067729          0.063745          0.139442        0.442231
#
#      budgeted_amount_FY16  budgeted_enrollment_FY16  budgeted_amount_FY17  \
# 0            1.059280e+07                      5880               3815456
# 2            7.429920e+06                      2650               3780814
# 3            8.979878e+06                      3660               4533018
# 4            1.519980e+07                      6340               7531184
# 5            1.102686e+07                      4340               5511270
# ..                    ...                       ...                   ...
# 104          1.745768e+07                      6860               8919967
# 105          1.243783e+07                      5270               6791997
# 106          7.133322e+06                      2510               3599053
# 107          8.835780e+06                      3610               4196996
# 108          7.232096e+06                      3620               3618704
#
#      budgeted_enrollment_FY17  kmeans_default_labels
# 0                     2674740                      0
# 2                     2499672                      1
# 3                     3020358                      1
# 4                     4677607                      0
# 5                     3506981                      1
# ..                        ...                    ...
# 104                   5286569                      4
# 105                   3355125                      5
# 106                   2721974                      6
# 107                   2765707                      3
# 108                   2887150                      6
#
# [107 rows x 28 columns]

# %%
kmeans.inertia_
# Out:
# 1241.9527502247201

# %%
# sns.pairplot(kmeans_df, hue='kmeans_default_labels', corner=True);

# %%
kmeans_df.groupby('kmeans_default_labels').mean().head(2)
# Out:
#                        enrollment_SY1718  enrollment_SY1819  \
# kmeans_default_labels
# 0                                440.125         450.218750
# 1                                335.500         329.264706
#
#                        star_score_SY1718  star_score_SY1819  \
# kmeans_default_labels
# 0                              72.871563          73.110625
# 1                              32.611176          37.674412
#
#                        star_rating_SY1718  star_rating_SY1819  \
# kmeans_default_labels
# 0                                4.093750            4.156250
# 1                                2.117647            2.411765
#
#                        capacity_SY1718  capacity_SY1819   latitude  longitude  \
# kmeans_default_labels
# 0                           488.312500       491.437500  38.922752 -77.037153
# 1                           444.941176       447.882353  38.877700 -76.972139
#
#                        ...  pct_20+_SY1819  pct_0_SY1718  pct_1-5_SY1718  \
# kmeans_default_labels  ...
# 0                      ...        0.031560      0.296834        0.562255
# 1                      ...        0.082571      0.189999        0.359361
#
#                        pct_6-10__SY1718  pct_11-20_SY1718  pct_20+_SY1718  \
# kmeans_default_labels
# 0                              0.102556          0.028491        0.009864
# 1                              0.241173          0.150683        0.058784
#
#                        budgeted_amount_FY16  budgeted_enrollment_FY16  \
# kmeans_default_labels
# 0                              1.007037e+07               4432.812500
# 1                              8.452657e+06               3427.058824
#
#                        budgeted_amount_FY17  budgeted_enrollment_FY17
# kmeans_default_labels
# 0                              4.991216e+06              3.619913e+06
# 1                              4.408448e+06              3.022196e+06
#
# [2 rows x 26 columns]

# %%
kmeans = KMeans(n_clusters=11)
kmeans.fit(X_ohe_ss)
# Out:
# KMeans(n_clusters=11)

# %%
kmeans_df = X.copy()
kmeans_df['kmeans_default_labels'] = kmeans.labels_
kmeans_df.head(2)
# Out:
#    grade_band  enrollment_SY1718  enrollment_SY1819  star_score_SY1718  \
# 0  Elementary                308                313              88.55
# 2  Elementary                243                244              43.85
#
#    star_score_SY1819  star_rating_SY1718  star_rating_SY1819  capacity_SY1718  \
# 0              88.26                   5                   5              444
# 2              10.79                   3                   1              529
#
#    capacity_SY1819   latitude  ...  pct_0_SY1718  pct_1-5_SY1718  \
# 0              444  38.897565  ...      0.379870        0.538961
# 2              529  38.897002  ...      0.271605        0.304527
#
#    pct_6-10__SY1718  pct_11-20_SY1718  pct_20+_SY1718  budgeted_amount_FY16  \
# 0          0.064935          0.016234        0.000000          1.059280e+07
# 2          0.238683          0.135802        0.049383          7.429920e+06
#
#    budgeted_enrollment_FY16  budgeted_amount_FY17  budgeted_enrollment_FY17  \
# 0                      5880               3815456                   2674740
# 2                      2650               3780814                   2499672
#
#    kmeans_default_labels
# 0                      1
# 2                      7
#
# [2 rows x 28 columns]

# %%
kmeans.inertia_
# Out:
# 1077.5795858784873

# %%
# sns.pairplot(kmeans_df, hue='kmeans_default_labels', corner=True);
# plt.savefig(f'kmeans_k=11_results')

# %%
kmeans_df.groupby('kmeans_default_labels').mean().head(2)
# Out:
#                        enrollment_SY1718  enrollment_SY1819  \
# kmeans_default_labels
# 0                             461.153846         456.230769
# 1                             439.583333         447.250000
#
#                        star_score_SY1718  star_score_SY1819  \
# kmeans_default_labels
# 0                              48.813846          52.329231
# 1                              71.928333          71.135833
#
#                        star_rating_SY1718  star_rating_SY1819  \
# kmeans_default_labels
# 0                                2.769231            3.153846
# 1                                4.041667            4.125000
#
#                        capacity_SY1718  capacity_SY1819   latitude  longitude  \
# kmeans_default_labels
# 0                           596.461538       596.461538  38.926743 -77.015171
# 1                           484.541667       488.708333  38.928879 -77.041146
#
#                        ...  pct_20+_SY1819  pct_0_SY1718  pct_1-5_SY1718  \
# kmeans_default_labels  ...
# 0                      ...        0.050394      0.192716        0.415573
# 1                      ...        0.034866      0.333443        0.531653
#
#                        pct_6-10__SY1718  pct_11-20_SY1718  pct_20+_SY1718  \
# kmeans_default_labels
# 0                              0.217696          0.128268        0.045748
# 1                              0.096396          0.028765        0.009743
#
#                        budgeted_amount_FY16  budgeted_enrollment_FY16  \
# kmeans_default_labels
# 0                              1.081757e+07               4133.000000
# 1                              9.966329e+06               4419.583333
#
#                        budgeted_amount_FY17  budgeted_enrollment_FY17
# kmeans_default_labels
# 0                              5.885558e+06              3.824086e+06
# 1                              4.862268e+06              3.547414e+06
#
# [2 rows x 26 columns]

# %%
def find_best_silhouette_kmeans(df): 
    max_score=-1
    for k in range(1,20):
        kmeans = KMeans(n_clusters=k).fit(df)
        if len(set(kmeans.labels_)) > 1:
            score = silhouette_score(df, kmeans.labels_)
            nclusters = len(set(kmeans.labels_))
            if score > max_score:
                max_score = score
                inertia = kmeans.inertia_
                best_clusters = nclusters
    print(f'Best silhouette score was {round(max_score, 2)}')
    print(f'Model inertia was {inertia}')
    print(f'Model found {best_clusters} clusters.')
    return

# %%
def find_best_silhouette_dbscan(df): 
    max_score=-1     

    for eps in np.linspace(.2, 5, 50):
        for minsamples in range(2, len(df/2)):
            dbscan = DBSCAN(eps=eps, min_samples=minsamples)
            dbscan.fit(df)
            if len(set(dbscan.labels_)) > 1:
                score = silhouette_score(df, dbscan.labels_)
                nclusters = len(set(dbscan.labels_))
                if score > max_score:
                    max_score = score
                    best_eps = eps
                    best_minsamples = minsamples
                    best_clusters = nclusters
    print(f'Best silhouette score was {round(max_score, 2)}')
    print(f'Best eps was {round(best_eps, 2)}')
    print(f'Best min_samples was {best_minsamples}.')
    print(f'Model found {best_clusters} clusters.')
    return

# %%
find_best_silhouette_dbscan(X_ohe_ss)
# Out:
# Best silhouette score was 0.32
# Best eps was 5.0
# Best min_samples was 7.
# Model found 2 clusters.

# %%
find_best_silhouette_kmeans(X_ohe_ss)
# Out:
# c:\programdata\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# Best silhouette score was 0.28
# Model inertia was 1112.791630103687
# Model found 10 clusters.

# %%
Sum_of_squared_distances = []
K = range(1,20)
for k in K:
    km = KMeans(n_clusters=k)
    km = km.fit(X_ohe_ss)
    Sum_of_squared_distances.append(km.inertia_)
# Out:
# c:\programdata\miniconda3\lib\site-packages\sklearn\cluster\_kmeans.py:881: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(

# %%
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()
# plt.savefig(f'elbow_plot_kmeans_results')

# %% [markdown]
# ### Would have expected k cluster of closer to 6 not 11 ....

# %%
pca = PCA()
X_ohe_ss_pca = pca.fit_transform(X_ohe_ss)

# %%
X_ohe_ss_pca.shape
# Out:
# (107, 31)

# %%
pca.explained_variance_
# Out:
# array([9.23255172e+00, 7.98085561e+00, 3.10411808e+00, 2.19823442e+00,
#        1.52864958e+00, 1.27106308e+00, 1.15063230e+00, 9.91575884e-01,
#        6.12170731e-01, 5.49416864e-01, 5.05561345e-01, 4.26746118e-01,
#        4.02624352e-01, 3.24929281e-01, 2.46060739e-01, 1.75691010e-01,
#        1.56449265e-01, 1.00574168e-01, 8.08695151e-02, 6.93348109e-02,
#        5.13718223e-02, 4.42116541e-02, 3.45419510e-02, 2.12571790e-02,
#        1.78590473e-02, 7.48072059e-03, 6.66484423e-03, 9.56738071e-04,
#        2.08547097e-18, 1.89712216e-18, 2.38320412e-32])

# %%
plt.plot(np.cumsum(pca.explained_variance_))
plt.title("CumSum PCA Explained Variance Plot");
# plt.savefig(f'cumsum_plot_pca_results')

# %%
plt.bar(range(10), pca.explained_variance_ratio_[:10])
plt.title("PCA Explained Variance Ratio Plot");
# plt.savefig(f'exp_var_ratio_plot_pca_results')

# %%
np.cumsum(pca.explained_variance_ratio_[:10])
# Out:
# array([0.29504084, 0.55008175, 0.64927877, 0.71952684, 0.76837727,
#        0.80899611, 0.84576639, 0.87745377, 0.89701666, 0.91457414])

# %%
pca = PCA(4)
X_ohe_ss_pca = pca.fit_transform(X_ohe_ss)

# %%
plt.matshow(pca.components_)
plt.xticks(range(len(X.columns)), X.columns, rotation = 90);
plt.colorbar();
plt.title("PCA Components Top 4 Plot");
# plt.savefig(f'pca4_components_plot_results')

# %%
pca.components_[0]
# Out:
# array([ 0.07098488,  0.02355903, -0.06636512, -0.0659712 ,  0.01453673,
#         0.13192521,  0.14748992,  0.27903775,  0.27592877,  0.25296165,
#         0.25756136,  0.0326011 ,  0.0333796 ,  0.19788122, -0.23835619,
#        -0.23114803, -0.23546151,  0.13188198,  0.25942209, -0.16625891,
#        -0.25884753, -0.15874282,  0.18256145,  0.24329994, -0.18496803,
#        -0.25127184, -0.18348346,  0.05573137,  0.09667322,  0.04836583,
#         0.10985406])

# %%
pca.components_.sum(axis = 1)
# Out:
# array([ 0.80476253,  2.47304632, -1.95405422,  0.29406086])
